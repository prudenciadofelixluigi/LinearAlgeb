# %% [markdown]
# <a href="https://colab.research.google.com/github/prudenciadofelixluigi/LinearAlgeb/blob/main/Plotting_Vector_using_NumPy_and_MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this laboratory we will be discussing the basics of numerical and scientific programming by working with Vectors using NumPy and MatPlotLib.
#
# Objectives
# At the end of this activity you will be able to:
#
# 1. Be familiar with the libraries in Python for numerical and scientific programming.
# 2. Visualize vectors through Python programming.
# 3. Perform simple vector operations through code.

# %% [markdown]
# # Discussion
#
# # NumPy
#
# NumPy or Numerical Python, is mainly used for matrix and vector operations. It is capable of declaring computing and representing matrices. Most Python scientific programming libraries uses NumPy as the basic code.
#
# Scalars \ Represent magnitude or a single value
#
# Vectors \ Represent magnitude with directors

# %% [markdown]
# # Representing Vectors
#
# Now that you know how to represent vectors using their component and matrix form we can now hard-code them in Python. Let's say that you have the vectors:
#
# $$ A = 4\hat{x} + 3\hat{y} \\
# B = 2\hat{x} - 5\hat{y}\\
# C = 4ax + 3ay - 2az \\
# D = 2\hat{i} - 2\hat{j} + 3\hat{k}$$
# In which it's matrix equivalent is:
#
# $$ A = \begin{bmatrix} 4 \\ 3\end{bmatrix} , B = \begin{bmatrix} 2 \\ -5\end{bmatrix} , C = \begin{bmatrix} 4 \\ 3 \\  -2 \end{bmatrix}, D = \begin{bmatrix} 2 \\ -2 \\ 3\end{bmatrix}
# $$$$ A = \begin{bmatrix} 4 & 3\end{bmatrix} , B = \begin{bmatrix} 2 & -5\end{bmatrix} , C = \begin{bmatrix} 4 & 3 & -2\end{bmatrix} , D = \begin{bmatrix} 2 & -2 & 3\end{bmatrix}
# $$
# We can then start doing numpy code with this by:

# %%
import numpy as np ## 'np' here is short-hand name of the library (numpy) or a nickname.

# %%
A = np.array([4, 3])
B = np.array([2, -5])
C = np.array([
              [4],
              [3],
              [-2]
])
D = np.array ([[2],
              [-2],
              [3]])
print('Vector A is ', A)
print('Vector B is ', B)
print('Vector C is ', C)
print('Vector D is ', D)
# Out:
# Vector A is  [4 3]
# Vector B is  [ 2 -5]
# Vector C is  [[ 4]
#  [ 3]
#  [-2]]
# Vector D is  [[ 2]
#  [-2]
#  [ 3]]

# %% [markdown]
# # Describing vectors in NumPy
#
# **Describing vectors** is very important if we want to perform basic to advanced operations with them. The fundamental ways in describing vectors are knowing their shape, size and dimensions.

# %%
A.shape
H = np.array([1, 0, 2, 5, -0.2, 0])
H.shape
# Out:
# (6,)

# %%
D.size
# Out:
# 3

# %% [markdown]
# # Addition
#
# The **addition** rule is simple, the we just need to add the elements of the matrices according to their index. So in this case if we add vector $A$ and vector $B$ we will have a resulting vector:
#
# $$R = 6\hat{x}-2\hat{y} \\ \\or \\ \\ R = \begin{bmatrix} 6 \\ -2\end{bmatrix} $$
# So let's try to do that in NumPy in several number of ways:

# %%
R = np.add(A, B) ## this is the functional method usisng the numpy library
P = np.add(C, D)

# %%
R = A + B   ## this is the explicit method, since Python does a value-reference so it can 
            ## know that these variables would need to do array operations.
R
# Out:
# array([ 6, -2])

# %%
pos1 = np.array([0,0,0])
pos2 = np.array([0,1,3])
pos3 = np.array([1,5,-2])
pos4 = np.array([5,-3,3])
#R = pos1 + pos2 + pos3 + pos4
#R = np.multiply(pos3, pos4)
R = pos3 / pos4
R
# Out:
# array([ 0.2       , -1.66666667, -0.66666667])

# %% [markdown]
# # Try for yourself!
#
# Try to implement subtraction, multiplication, and division with vectors $A$ and $B$!
#
# $$A = \begin{bmatrix}2 & -5\end{bmatrix}, B = \begin{bmatrix}-4 & 8\end{bmatrix}$$

# %%
vectA = np.array ([2, -5])
vectB = np.array ([-4, 8])
print(vectA)
print(vectB)
# Out:
# [ 2 -5]
# [-4  8]

# %% [markdown]
# # Subtraction of Vectors A and B

# %%
F = vectA - vectB
F
# Out:
# array([  6, -13])

# %%
pos1 = np.array([2, -5])
pos2 = np.array([-4, 8])

E = pos1 - pos2
E
# Out:
# array([  6, -13])

# %% [markdown]
# # **Flowchart**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Division of Vectors A and B

# %%
L = vectA / vectB
L
# Out:
# array([-0.5  , -0.625])

# %%
vect1 = np.array([2, -5])
vect2 = np.array([-4, 8])

I = vect1 / vect2
I
# Out:
# array([-0.5  , -0.625])

# %% [markdown]
# # **Flowchart**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Multiplication of Vectors A and B

# %%
X = vectA * vectB
X
# Out:
# array([ -8, -40])

# %%
vect1 = np.array([2, -5])
vect2 = np.array([-4, 8])

P = vect1 * vect2
P
# Out:
# array([ -8, -40])

# %% [markdown]
# # **Flowchart**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Scaling**
#
# Scaling or scalar multiplication takes a scalar value and performs multiplication with a vector. Let's take the example below:
#
# $$S = 5 \cdot A$$
# We can do this in numpy through:

# %%
#S = 5 * A
S = np.multiply(5,A)
S
# Out:
# array([20, 15])

# %% [markdown]
# # Try to implement scaling with two vectors.

# %%
R = -6 * vectA
R
## IN THIS CELL, THE PROGRAM CALLED THE ARRAYS OF VECT(A) WHICH IS  2 and -5 
## MULTIPLIED TO -6 or THE CODERS CAN SIMPLY USE 

## G = np.multiply(-6 , vectA)
## G
## THESE 2 DIFFERENT FUNCTION LEADS TO SAME RESULTS
# Out:
# array([-12,  30])

# %% [markdown]
# # **Flowchart**: **Multiplication**
# ![image.png](data:image/png;base64,...)

# %%
U = 10 / vectB
U

## IN THIS CELL, THE PROGRAM CALLED THE ARRAYS OF VECT(B) WHICH IS 4 and 8  
## DIVIDED TO 10 or THE CODERS CAN SIMPLY USE 

## D = np.divide(-6 , vectA)
## D

## THESE 2 DIFFERENT FUNCTION LEADS TO SAME RESULTS.
# Out:
# array([-2.5 ,  1.25])

# %% [markdown]
# # **Flowchart**: **Division**
# ![image.png](data:image/png;base64,...)

# %%
A = 4 - vectA
A
## IN THIS CELL, THE PROGRAM CALLED THE ARRAYS OF VECT(A) WHICH IS 2 and -5  
## SUBTRACTED TO 4 or THE CODERS CAN SIMPLY USE 
##A = np.subtract(4, vectA)
##A
# Out:
# array([2, 9])

# %% [markdown]
# # **Flowchart**: **Subtraction**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **MatPlotLib**
# MatPlotLib or MATLab Plotting library is Python's take on MATLabs plotting feature. MatPlotLib can be used vastly from graping values to visualizing several dimensions of data.
#
# Visualizing Data
# It's not enough just solving these vectors so might need to visualize them. So we'll use MatPlotLib for that. We'll need to import it first.

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
A = [1, -1]
B = [5, 2]
plt.scatter(A[0], A[1], label='A', c='green')
plt.scatter(B[0], B[1], label='B', c='magenta')
plt.grid()
plt.legend()
plt.show()

# %%
A = np.array([1, -1])
B = np.array([1, 5])
plt.title("Resultant Vector\nMagnitude:{}" .format(Magnitude))
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
R = A + B
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R**2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [2 4]
# 4.47213595499958
# 2.0
# 63.43494882292201

# %% [markdown]
# # Try plotting Three Vectors and show the Resultant Vector as a result. Use Head to Tail Method.

# %%
A = np.array([1, -3])
B = np.array([1, -1])
C = np.array([1, -1])
plt.title("Resultant Vector\nMagnitude:{}")
plt.xlim(-5, 10)
plt.ylim(-5, 10)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
plt.quiver(2, -4, C[0], C[1], angles='xy', scale_units='xy', scale=1, color='blue')
R = A + B + C
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R**2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [ 3 -5]
# 5.830951894845301
# -1.6666666666666667
# -59.03624346792648

# %% [markdown]
# # **Flowchart: Matplotlib**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusion**
#
# In this activity, it showed that calculations are not the only functions that the Python Programming can perform but also in plotting different types of plotsuch as Bar Graph, Scatter Plot, Box Plot etc. with the use of the function key numpy (use to perform arrays given in each sets) and matplotlib (creates lines or animations for plotting). For that reason, Python Programming has various functions and commands which will be learned in the future discussions
